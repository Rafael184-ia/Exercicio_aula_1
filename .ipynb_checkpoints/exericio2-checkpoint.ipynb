# %%
idade = int(input("Digite sua iadade: "))

if idade <= 13 :
    print("Crianca")
elif idade <= 17:
    print("Adolescente")
else :
    print("Adulto")
# Out:
# Digite sua iadade:  10
# Crianca

# %% [markdown]
# Exercicio1

# %%
numero = int(input("Digite um numero: "))

if numero == numero > 0:
    print("O numero é positivo bb")
# Out:
# Digite um numero:  10
# O numero é positivo bb

# %% [markdown]
# Exercicio2

# %%
idade = int(input("Digite sua idade: "))

if idade >= 18:
    print("Maior de idade")
# Out:
# Digite sua idade:  19
# Maior de idade

# %% [markdown]
# Exercicio3

# %%
numero = int(input("Digite um numero: "))

if numero > 10:
    print("O numero é maior que 10")
# Out:
# Digite um numero:  11
# O numero é maior que 10

# %% [markdown]
# Exercicio4

# %%
numero = int(input("Digite um numero inteiro: "))
if numero % 2 == 0:
    print("Numero par")

else:
    print("Numero impar")
# Out:
# Digite um numero inteiro:  10
# Numero par

# %% [markdown]
# ##### Exercicio5

# %%
nota = int(input("digite sua nota : "))
if nota >= 7 :
    print("APROVADO")
else:
    print("RECUPERACAO")
# Out:
# digite sua nota :  8
# APROVADO

# %% [markdown]
# exercicio 6

# %%
numero1 = int(input("digite um numero; "))
numero2 = int(input("digite outro numero: "))

if numero1 > numero2:
    print(Numero1," é o maior")
else:
    print(numero2 ," é maior")
# Out:
# digite um numero;  1
# digite outro numero:  4
# 4  é maior

# %% [markdown]
# Exercicio8

# %%
idade = int(input("Digite sua nota: "))

if nota >= 7 :
    print("APROVADO")
elif nota <= 6:
    print("RECUPERACAO")
else :
    print("REPROVADO")
# Out:
# Digite sua nota:  9
# APROVADO

# %% [markdown]
# exercicio7

# %%
idade = int(input("Digite sua iadade: "))

if idade <= 13 :
    print("Crianca")
elif idade <= 17:
    print("Adolescente")
else :
    print("Adulto")
# Out:
# Digite sua iadade:  20
# Adulto

# %% [markdown]
# exercicio9

# %%
numero1 = int(input("Digite um numero: "))
numero2 = int(input("digite outro numero: "))
numero3 = int(input("digite mais um: "))

maior = numero1

if numero2 > maior:
    maior=numero2

if numero3 > maior:
    maior = numero3

print("O maior é o  ",maior)
# Out:
# Digite um numero:  76
# digite outro numero:  90
# digite mais um:  1
# O maior é o   90

# %% [markdown]
# exercicio 10

# %%
usuario_correto = "admin"
senha = "1234"

usuario = input("digite o nome de usuario: ")
senha = input("digite a senha: ")

if usuario == usuario_correto and senha :
    print("login realizado com sucesso")
# Out:
# digite o nome de usuario:  admin
# digite a senha:  1234
# login realizado com sucesso

# %% [markdown]
# Desafio extra

# %%
numero1 = int(input("Digite um numero: "))


if numero1 > 0:
    print("Numero positivo")

elif numero1 < 0:
    print("numero negativo")

else:
    print("numero igual a 0")
# Out:
# Digite um numero:  0
# numero igual a 0
