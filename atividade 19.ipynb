# %%
#verificacao de maioridade
idade_usuario = int(input("type your age: "))
idade_usuario
# Out:
# digite a sua idade 13
# 13

# %%
if idade_usuario >= 18:
    print("Your not have age for enter")

else:
    print("Your have age for enter")
# Out:
# Voce nao tem idade para entrar

# %%
#verificar a aprovacao
grade = int(input("type your school grade: "))
grade
# Out:
# type your school grade:  6
# 6

# %%
if grade >= 7:
    print("Good , you aprovedd")
elif grade >= 5:
    print("Your are of recupation")
elif grade < 0:
    print("Negative grade????GOTIIII")
else:
    print("Sorry,your reprovedd")
# Out:
# Your are of recupation

# %%
#Verificar "==" ou "!="
number = float(input("type a number between -2 and 5 /n"))
number
# Out:
# type a number between -2 and 5 /n 3
# 3.0

# %%
if number == -1:
    print("Your right!!!!!!")
else:
    print("your LOSER!!!!!")
# Out:
# your LOSER!!!!!

# %%
if number != 3:
    print("Sorry you not right")
else:
    print("Good this is right number")
# Out:
# Good this is right number

# %%
#Resto da divisao por um numero "%"
number = int(input("type a natural number: "))
if number % 2 == 0:
    print(f"the number {number}  is pair")
else:
    print(f"the {number} not's pair")
# Out:
# type a natural number:  4
# the number 4  is pair

# %%
#comparar dois numeros
number = float(input("type an number: "))
number2 = float(input("type an other number: "))

if number > number2:
    print(f"the number {number} is a big number")
    
elif number == number2:
    print("the two numbers are equals")
else:
    print(f"the number {number2} is a big number")
# Out:
# type an number:  6
# type an other number:  9
# the number 9.0 is a big number

# %%
a = float(input("Digite o valor do coefisciente a"))
b = float(input("Digite o valor do coefisciente b"))
c = float(input("Digite p valor do coefisciente c"))

delta = b**2 - 4*a*c
x1 = (-b + delta**(0.5))/(2*a)
x2 = (-b - delta**(0.5))/(2*a)
if delta < 0:
    print(f"Delta menor que zero : {delta}")
    print("Nao existe raiz real")
elif a == 0:
    print(f"{a} é menor que ,insira um numero diferente")
    
elif delta ==0:
    print(f" x'={x1} = x'' ={x2}")
else:
    print(f"x' = {x1} e x'' = {x2}")
# Out:
# Digite o valor do coefisciente a -2
# Digite o valor do coefisciente b 5
# Digite p valor do coefisciente c -3
# x' = 1.0 e x'' = 1.5
