# %%
#exercicio 1 
print("Eu estou aprendendo python bbs")
# Out:
# Eu estou aprendendo python bbs

# %%
#exercicio 2 
nome = "maria"
lugar = "recife"
print("meu nome é ", nome)
print("eu moro em ", lugar)
# Out:
# meu nome é  maria
# eu moro em  recife

# %%
#exerccio 3 
nome_de_aluno = "Ana"
idade_de_aluno = 65
print("meu nome é" , nome_de_aluno , "e tenho" , idade_de_aluno , "anos")
# Out:
# meu nome é Ana e tenho 65 anos

# %%
#exercicio 4
cidade = "Goiânia"
estado = "GO"
pais = "Brasil"
print("eu moro em", cidade , " - " ,estado," , ",  pais)
# Out:
# eu moro em Goiânia  -  GO  ,  Brasil
